# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from copy import deepcopy

import pickle

print(os.getcwd())
if os.getcwd().split("/")[-1] == "Covid_19_predictor":
  print("Current working directory is already Covid_19_predictor")
elif os.path.isdir("Covid_19_predictor"):
  print("Covid_19_predictor already Exists")
else:
  ! git clone https://github.com/saahil-jain/Covid_19_predictor.git
# Out:
# /content
# Covid_19_predictor already Exists

# %%
if os.path.isdir("Covid_19_predictor"):
  % cd Covid_19_predictor
! git pull
# Out:
# /content/Covid_19_predictor
# Already up to date.

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#       dateRep  day  month  ...  countryterritoryCode  popData2018  continentExp
# 0  05/06/2020    5      6  ...                   AFG   37172386.0          Asia
# 1  04/06/2020    4      6  ...                   AFG   37172386.0          Asia
# 2  03/06/2020    3      6  ...                   AFG   37172386.0          Asia
# 3  02/06/2020    2      6  ...                   AFG   37172386.0          Asia
# 4  01/06/2020    1      6  ...                   AFG   37172386.0          Asia
#
# [5 rows x 11 columns]

# %%
grouped = df.groupby('countriesAndTerritories')
countries = sorted(list(set(df.countriesAndTerritories.unique())))
country_population = {}
for country in countries:
  country_population[country] = set(grouped.get_group(country)['popData2018'])
countries_to_remove = ["Cases_on_an_international_conveyance_Japan", "Holy_See"]
for country in countries:
  if len(country_population[country])>1 :
    countries_to_remove.append(country)
for country in countries_to_remove:
  del country_population[country]
  countries.remove(country)

country_population = {}
for country in countries:
  country_population[country] = list(grouped.get_group(country)['popData2018'])[0]

# %%
country_wise_cases = dict()
country_wise_deaths = dict()
normalised_country_wise_cases = dict()
normalised_country_wise_deaths = dict()
for country in countries:
  country_wise_cases[country] = list(grouped.get_group(country)['cases'])[::-1]
  country_wise_deaths[country] = list(grouped.get_group(country)['deaths'])[::-1]
for country in countries:
  for index in range(len(country_wise_cases[country])):
    country_wise_cases[country][index] = abs(country_wise_cases[country][index])
    country_wise_deaths[country][index] = abs(country_wise_deaths[country][index])

for country in countries:
  leading_zero_count = 0
  for index in range(len(country_wise_cases[country])):
    if country_wise_cases[country][index] == 0:
      leading_zero_count += 1
    else:
      country_wise_cases[country] = country_wise_cases[country][leading_zero_count:]
      country_wise_deaths[country] = country_wise_deaths[country][leading_zero_count:]
      break

# %%
for country in countries:
  graph = plt.plot(country_wise_cases[country])
plt.show()

for country in countries:
  normalised_country_wise_cases[country] = deepcopy(country_wise_cases[country])
  for index in range(len(country_wise_cases[country])):
    normalised_country_wise_cases[country][index] = normalised_country_wise_cases[country][index] * 1_000_000 / country_population[country]
  graph=plt.plot(normalised_country_wise_cases[country])
plt.show()

# %%
for country in countries:
  graph = plt.plot(country_wise_deaths[country])
plt.show()

for country in countries:
  normalised_country_wise_deaths[country] = deepcopy(country_wise_deaths[country])
  for index in range(len((country_wise_deaths[country]))):
    normalised_country_wise_deaths[country][index] = normalised_country_wise_deaths[country][index] * 1_000_000 / country_population[country]
  graph = plt.plot(normalised_country_wise_deaths[country])
plt.show()

# %%
cumulative_country_wise_cases = dict()
cumulative_country_wise_deaths = dict()
normalised_cumulative_country_wise_cases = dict()
normalised_cumulative_country_wise_deaths = dict()

for country in countries:
  cumulative_country_wise_cases[country] = []
  cumulative_country_wise_deaths[country] = []
  cumulative_cases = 0
  cumulative_death = 0
  normalised_cumulative_country_wise_cases[country] = []
  normalised_cumulative_country_wise_deaths[country] = []
  normalised_cumulative_cases = 0
  normalised_cumulative_death = 0
  total_days = len(country_wise_cases[country])
  for index in range(total_days):
    cumulative_cases += country_wise_cases[country][index]
    cumulative_death += country_wise_deaths[country][index]
    cumulative_country_wise_cases[country].append(cumulative_cases)
    cumulative_country_wise_deaths[country].append(cumulative_death)
    normalised_cumulative_cases += normalised_country_wise_cases[country][index]
    normalised_cumulative_death += normalised_country_wise_deaths[country][index]
    normalised_cumulative_country_wise_cases[country].append(normalised_cumulative_cases)
    normalised_cumulative_country_wise_deaths[country].append(normalised_cumulative_death)

# %%
for country in countries:
  graph = plt.plot(cumulative_country_wise_cases[country])
plt.show()

for country in countries:
  graph = plt.plot(normalised_cumulative_country_wise_cases[country])
plt.show()

# %%
for country in countries:
  graph = plt.plot(cumulative_country_wise_deaths[country])
plt.show()

for country in countries:
  graph = plt.plot(normalised_cumulative_country_wise_deaths[country])
plt.show()

# %%
for country in countries:
  print("{0:45s}".format(country),"{0:10d}".format(cumulative_country_wise_cases[country][-1]),"{0:10d}".format(cumulative_country_wise_deaths[country][-1]))
# Out:
# Afghanistan                                        18054        300
# Albania                                             1197         33
# Algeria                                             9831        681
# Andorra                                              852         51
# Angola                                                86          4
# Antigua_and_Barbuda                                   26          3
# Argentina                                          19255        588
# Armenia                                            11221        176
# Aruba                                                101          3
# Australia                                           7240        102
# Austria                                            16741        670
# Azerbaijan                                          6522         78
# Bahamas                                              102         11
# Bahrain                                            13296         21
# Bangladesh                                         57563        781
# Barbados                                              92          7
# Belarus                                            45981        253
# Belgium                                            58767       9548
# Belize                                                18          2
# Benin                                                679          3
# Bermuda                                              141          9
# Bhutan                                                48          0
# Bolivia                                            12245        415
# Bosnia_and_Herzegovina                              2593        158
# Botswana                                              40          1
# Brazil                                            614941      34021
# British_Virgin_Islands                                 8          1
# Brunei_Darussalam                                    141          2
# Bulgaria                                            2585        147
# Burkina_Faso                                         885         53
# Burundi                                               63          1
# Cambodia                                             125          0
# Cameroon                                            6789        203
# Canada                                             93715       7637
# Cape_Verde                                           502          5
# Cayman_Islands                                       160          1
# Central_African_Republic                            1288          4
# Chad                                                 828         66
# Chile                                             118292       1356
# China                                              84171       4638
# Colombia                                           35120       1087
# Comoros                                              132          2
# Congo                                                635         20
# Costa_Rica                                          1194         10
# Cote_dIvoire                                        3262         35
# Croatia                                             2247        103
# Cuba                                                2119         83
# Curaçao                                               21          1
# Cyprus                                               958         17
# Czechia                                             9494        326
# Democratic_Republic_of_the_Congo                    3643         78
# Denmark                                            11811        582
# Djibouti                                            4054         26
# Dominica                                              18          0
# Dominican_Republic                                 18319        520
# Ecuador                                            48948       3486
# Egypt                                              29767       1126
# El_Salvador                                         2781         52
# Equatorial_Guinea                                   1306         12
# Estonia                                             1890         69
# Eswatini                                             300          3
# Ethiopia                                            1636         18
# Faroe_Islands                                        187          0
# Fiji                                                  18          0
# Finland                                             6911        322
# France                                            153976      29065
# French_Polynesia                                      60          0
# Gabon                                               2955         21
# Gambia                                                26          1
# Georgia                                              801         13
# Germany                                           183271       8613
# Ghana                                               8885         38
# Gibraltar                                            173          0
# Greece                                              2937        179
# Greenland                                             13          0
# Grenada                                               23          0
# Guam                                                 179          5
# Guatemala                                           6154        158
# Guernsey                                             252         13
# Guinea                                              3991         23
# Guinea_Bissau                                       1346          9
# Guyana                                               153         12
# Haiti                                               2640         50
# Honduras                                            5880        243
# Hungary                                             3954        539
# Iceland                                             1806         10
# India                                             226770       6348
# Indonesia                                          28818       1721
# Iran                                              164270       8071
# Iraq                                                8840        271
# Ireland                                            25142       1664
# Isle_of_Man                                          336         24
# Israel                                             17562        291
# Italy                                             234013      33689
# Jamaica                                              591         10
# Japan                                              17064        907
# Jersey                                               309         30
# Jordan                                               765          9
# Kazakhstan                                         12312         52
# Kenya                                               2340         78
# Kosovo                                              1142         30
# Kuwait                                             29921        236
# Kyrgyzstan                                          1936         22
# Laos                                                  19          0
# Latvia                                              1082         25
# Lebanon                                             1306         28
# Lesotho                                                4          0
# Liberia                                              321         28
# Libya                                                196          5
# Liechtenstein                                         83          1
# Lithuania                                           1897         71
# Luxembourg                                          4027        110
# Madagascar                                           957          7
# Malawi                                               393          4
# Malaysia                                            7970        115
# Maldives                                            1872          7
# Mali                                                1461         85
# Malta                                                622          9
# Mauritania                                           784         39
# Mauritius                                            335         10
# Mexico                                            105680      12545
# Moldova                                             9018        315
# Monaco                                                99          5
# Mongolia                                             191          0
# Montenegro                                           324          9
# Montserrat                                            11          1
# Morocco                                             8003        208
# Mozambique                                           352          2
# Myanmar                                              236          6
# Namibia                                               25          0
# Nepal                                               2634         10
# Netherlands                                        46942       5990
# New_Caledonia                                         20          0
# New_Zealand                                         1154         22
# Nicaragua                                           1118         46
# Niger                                                963         65
# Nigeria                                            11516        323
# North_Macedonia                                     2612        147
# Northern_Mariana_Islands                              26          2
# Norway                                              8477        238
# Oman                                               14316         67
# Pakistan                                           89249       1838
# Palestine                                            643          5
# Panama                                             15044        535
# Papua_New_Guinea                                       8          0
# Paraguay                                            1086         11
# Peru                                              183198       5031
# Philippines                                        20382        984
# Poland                                             25048       1117
# Portugal                                           33914       1455
# Puerto_Rico                                         4508        140
# Qatar                                              63741         45
# Romania                                            19907       1299
# Russia                                            441108       5384
# Rwanda                                               410          2
# Saint_Kitts_and_Nevis                                 15          0
# Saint_Lucia                                           19          0
# Saint_Vincent_and_the_Grenadines                      26          0
# San_Marino                                           705         42
# Sao_Tome_and_Principe                                499         12
# Saudi_Arabia                                       93157        611
# Senegal                                             4021         45
# Serbia                                             11571        246
# Seychelles                                            11          0
# Sierra_Leone                                         914         47
# Singapore                                          36922         24
# Sint_Maarten                                          77         15
# Slovakia                                            1526         28
# Slovenia                                            1477        108
# Somalia                                             2204         79
# South_Africa                                       40792        848
# South_Korea                                        11668        273
# South_Sudan                                         1317         14
# Spain                                             242830      31776
# Sri_Lanka                                           1797         11
# Sudan                                               5499        314
# Suriname                                              82          1
# Sweden                                             41883       4562
# Switzerland                                        30830       1659
# Syria                                                124          6
# Taiwan                                               443          7
# Tajikistan                                          4289         48
# Thailand                                            3102         58
# Timor_Leste                                           24          0
# Togo                                                 465         13
# Trinidad_and_Tobago                                  117          8
# Tunisia                                             1087         49
# Turkey                                            167410       4630
# Turks_and_Caicos_islands                              12          1
# Uganda                                               754          0
# Ukraine                                            25964        762
# United_Arab_Emirates                               37018        273
# United_Kingdom                                    282711      39904
# United_Republic_of_Tanzania                          509         21
# United_States_Virgin_Islands                          71          6
# United_States_of_America                         1872660     108211
# Uruguay                                              832         23
# Uzbekistan                                          3965         16
# Venezuela                                           2087         20
# Vietnam                                              328          0
# Yemen                                                453        103
# Zambia                                              1111          7
# Zimbabwe                                             237          4

# %%
top_n = 10
countries_and_cases=[]
countries_and_deaths=[]

for country, cumulative_cases in zip(cumulative_country_wise_cases.keys(), cumulative_country_wise_cases.values()):
  countries_and_cases.append([country, cumulative_cases[-1]])
countries_and_cases = sorted(countries_and_cases,key = lambda x:x[1],reverse=True)
top_n_cases = list(map(lambda x:x[0], countries_and_cases))[:top_n]

for country, cumulative_deaths in zip(cumulative_country_wise_deaths.keys(), cumulative_country_wise_deaths.values()):
  countries_and_deaths.append([country, cumulative_deaths[-1]])
countries_and_deaths = sorted(countries_and_deaths, key = lambda x:x[1], reverse = True)

top_n_deaths = list(map(lambda x:x[0],countries_and_deaths))[:top_n]

print("{0:45s}".format("Total Cases"), "{0:45s}".format("Total Deaths"), end="\n\n")
for index in range(top_n):
  print("{0:45s}".format(top_n_cases[index]), "{0:45s}".format(top_n_deaths[index]))
# Out:
# Total Cases                                   Total Deaths
#
# United_States_of_America                      United_States_of_America
# Brazil                                        United_Kingdom
# Russia                                        Brazil
# United_Kingdom                                Italy
# Spain                                         Spain
# Italy                                         France
# India                                         Mexico
# Germany                                       Belgium
# Peru                                          Germany
# Turkey                                        Iran

# %%
def intersection(lst1, lst2): 
  return list(set(lst1) & set(lst2)) 
training_countries = list(intersection(top_n_cases, top_n_deaths))
print(training_countries)
# Out:
# ['Germany', 'United_Kingdom', 'Spain', 'United_States_of_America', 'Brazil', 'Italy']

# %%
plt.style.use('seaborn-whitegrid')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional, SimpleRNN
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.

# %%
def return_rmse(test,predicted):
  rmse = math.sqrt(mean_squared_error(test, predicted))
  print("The root mean squared error is {}.".format(rmse))

# %%
base_data_cases = normalised_country_wise_cases
base_data_deaths = normalised_country_wise_deaths

def split(dataframe, split_factor):
  base_data = {}
  for country in training_countries:
    base_data[country] = {}
    country_data_length = len(dataframe[country])
    split_index = int(math.floor(country_data_length * split_factor))
    base_data[country]["Train"] = dataframe[country][:split_index]
    base_data[country]["Test"] = dataframe[country][split_index:]
  return base_data

split_factor = 0.8

transform_train_cases = {}
transform_test_cases = {}
scaler_cases = {}
data_cases = split(base_data_cases, split_factor)
for num, country in enumerate(training_countries):
  sc = MinMaxScaler(feature_range=(0,1))
  a0 = np.array(data_cases[country]["Train"])
  a1 = np.array(data_cases[country]["Test"])
  a0 = a0.reshape(a0.shape[0],1)
  a1 = a1.reshape(a1.shape[0],1)
  transform_train_cases[country] = sc.fit_transform(a0)
  transform_test_cases[country] = sc.fit_transform(a1)
  scaler_cases[country] = sc
del a0
del a1

transform_train_deaths = {}
transform_test_deaths = {}
scaler_deaths = {}
data_deaths = split(base_data_deaths, split_factor)
for num, country in enumerate(training_countries):
  sc = MinMaxScaler(feature_range=(0,1))
  a0 = np.array(data_deaths[country]["Train"])
  a1 = np.array(data_deaths[country]["Test"])
  a0 = a0.reshape(a0.shape[0],1)
  a1 = a1.reshape(a1.shape[0],1)
  transform_train_deaths[country] = sc.fit_transform(a0)
  transform_test_deaths[country] = sc.fit_transform(a1)
  scaler_deaths[country] = sc
del a0
del a1

# %%
for i in transform_train_cases.keys():
    print(i, transform_train_cases[i].shape)
print("\n")    
for i in transform_test_cases.keys():
    print(i, transform_test_cases[i].shape)
 
print("\n")    
for i in transform_train_deaths.keys():
    print(i, transform_train_deaths[i].shape)
print("\n")    
for i in transform_test_deaths.keys():
    print(i, transform_test_deaths[i].shape)
# Out:
# Germany (104, 1)
# United_Kingdom (101, 1)
# Spain (100, 1)
# United_States_of_America (109, 1)
# Brazil (80, 1)
# Italy (101, 1)
#
#
# Germany (26, 1)
# United_Kingdom (26, 1)
# Spain (25, 1)
# United_States_of_America (28, 1)
# Brazil (21, 1)
# Italy (26, 1)
#
#
# Germany (104, 1)
# United_Kingdom (101, 1)
# Spain (100, 1)
# United_States_of_America (109, 1)
# Brazil (80, 1)
# Italy (101, 1)
#
#
# Germany (26, 1)
# United_Kingdom (26, 1)
# Spain (25, 1)
# United_States_of_America (28, 1)
# Brazil (21, 1)
# Italy (26, 1)

# %%
trainset_cases = {}
testset_cases = {}
look_back_cases = 3
for country in training_countries:
    trainset_cases[country] = {}
    X_train = []
    y_train = []
    for i in range(look_back_cases, len(transform_train_cases[country])):
      X_train.append(transform_train_cases[country][i-look_back_cases:i,0])
      y_train.append(transform_train_cases[country][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset_cases[country]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset_cases[country]["y"] = y_train
    
    testset_cases[country] = {}
    X_test = []
    y_test = []    
    for i in range(look_back_cases, len(transform_test_cases[country])):
      X_test.append(transform_test_cases[country][i-look_back_cases:i,0])
      y_test.append(transform_test_cases[country][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset_cases[country]["X"] = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
    testset_cases[country]["y"] = y_test

trainset_deaths = {}
testset_deaths = {}
look_back_deaths = 3
for country in training_countries:
    trainset_deaths[country] = {}
    X_train = []
    y_train = []
    for i in range(look_back_deaths, len(transform_train_deaths[country])):
      X_train.append(transform_train_deaths[country][i-look_back_deaths:i,0])
      y_train.append(transform_train_deaths[country][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset_deaths[country]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset_deaths[country]["y"] = y_train
    
    testset_deaths[country] = {}
    X_test = []
    y_test = []    
    for i in range(look_back_deaths, len(transform_test_deaths[country])):
      X_test.append(transform_test_deaths[country][i-look_back_deaths:i,0])
      y_test.append(transform_test_deaths[country][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset_deaths[country]["X"] = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
    testset_deaths[country]["y"] = y_test

# %%
arr_buff_cases = []
for country in training_countries:
  buff = {}
  buff["X_train"] = trainset_cases[country]["X"].shape
  buff["y_train"] = trainset_cases[country]["y"].shape
  buff["X_test"] = testset_cases[country]["X"].shape
  buff["y_test"] = testset_cases[country]["y"].shape
  arr_buff_cases.append(buff)

pd.DataFrame(arr_buff_cases, index=training_countries)
# Out:
#                               X_train y_train      X_test y_test
# Germany                   (101, 3, 1)  (101,)  (23, 3, 1)  (23,)
# United_Kingdom             (98, 3, 1)   (98,)  (23, 3, 1)  (23,)
# Spain                      (97, 3, 1)   (97,)  (22, 3, 1)  (22,)
# United_States_of_America  (106, 3, 1)  (106,)  (25, 3, 1)  (25,)
# Brazil                     (77, 3, 1)   (77,)  (18, 3, 1)  (18,)
# Italy                      (98, 3, 1)   (98,)  (23, 3, 1)  (23,)

# %%
arr_buff_deaths = []
for country in training_countries:
  buff = {}
  buff["X_train"] = trainset_deaths[country]["X"].shape
  buff["y_train"] = trainset_deaths[country]["y"].shape
  buff["X_test"] = testset_deaths[country]["X"].shape
  buff["y_test"] = testset_deaths[country]["y"].shape
  arr_buff_deaths.append(buff)

pd.DataFrame(arr_buff_deaths, index=training_countries)
# Out:
#                               X_train y_train      X_test y_test
# Germany                   (101, 3, 1)  (101,)  (23, 3, 1)  (23,)
# United_Kingdom             (98, 3, 1)   (98,)  (23, 3, 1)  (23,)
# Spain                      (97, 3, 1)   (97,)  (22, 3, 1)  (22,)
# United_States_of_America  (106, 3, 1)  (106,)  (25, 3, 1)  (25,)
# Brazil                     (77, 3, 1)   (77,)  (18, 3, 1)  (18,)
# Italy                      (98, 3, 1)   (98,)  (23, 3, 1)  (23,)

# %%
total_error = dict()
total_error["Cases"] = 0
total_error["Deaths"] = 0
  
def lagging(df, lag):
  df_pred = pd.Series(df["Pred"].reshape(-1))
  df_true = pd.Series(df["True"].reshape(-1))
   
  df_pred_lag = df_pred.shift(lag)
    
  MSE_lag = mean_squared_error(np.array(df_true[:-lag]), np.array(df_pred_lag[:-lag]))
  print("MSE with Lag    :", MSE_lag)

  plt.figure(figsize=(14,4))
  plt.title("Prediction with Lag")
  plt.plot(df_true, color='green')
  plt.plot(df_pred_lag, color='blue')
  plt.legend(["True", "Predicted"])

  return MSE_lag

# %%
# %%time
# epochs = 5
# The RNN architecture
regressorRNN_cases = Sequential()
# First RNN layer with Dropout regularisation
regressorRNN_cases.add(SimpleRNN(units=50, return_sequences=True, input_shape=(look_back_cases,1), activation='tanh'))
regressorRNN_cases.add(Dropout(0.2))
# Second RNN layer
regressorRNN_cases.add(SimpleRNN(units=50, return_sequences=True, input_shape=(look_back_cases,1), activation='tanh'))
regressorRNN_cases.add(Dropout(0.2))
# Third RNN layer
regressorRNN_cases.add(SimpleRNN(units=50, return_sequences=True, input_shape=(look_back_cases,1), activation='tanh'))
regressorRNN_cases.add(Dropout(0.2))
# Fourth RNN layer
regressorRNN_cases.add(SimpleRNN(units=50, activation='tanh'))
regressorRNN_cases.add(Dropout(0.2))
# The output layer
regressorRNN_cases.add(Dense(units=1))
# Compiling the RNN
regressorRNN_cases.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error', metrics = ['accuracy'])
# Fitting to the training set
history_cases = {}
for country in training_countries:
  history_cases[country] = []

epochs = 16

for epoch in range(epochs):
    for country in training_countries:
        print("Fitting to", country)
        H = regressorRNN_cases.fit(trainset_cases[country]["X"], trainset_cases[country]["y"], epochs=1, batch_size=16)
        history_cases[country].append(H.history["loss"])
print(history_cases)

plt.style.use("ggplot")
plt.figure()
for country in training_countries:
  plt.plot(np.arange(0, epochs), history_cases[country], label=country)
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="upper right")
# Out:
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 5ms/step - loss: 0.1493 - accuracy: 0.1881
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 259us/step - loss: 0.1420 - accuracy: 0.2041
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 256us/step - loss: 0.0913 - accuracy: 0.2062
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 228us/step - loss: 0.0646 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 248us/step - loss: 0.0512 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 251us/step - loss: 0.0806 - accuracy: 0.1939
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 231us/step - loss: 0.0717 - accuracy: 0.1881
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 305us/step - loss: 0.0426 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 298us/step - loss: 0.0359 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 294us/step - loss: 0.0312 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 287us/step - loss: 0.0267 - accuracy: 0.0779
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 257us/step - loss: 0.0292 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 292us/step - loss: 0.0363 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 251us/step - loss: 0.0163 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 257us/step - loss: 0.0193 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 253us/step - loss: 0.0153 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 284us/step - loss: 0.0174 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 258us/step - loss: 0.0219 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 254us/step - loss: 0.0280 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 259us/step - loss: 0.0128 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 260us/step - loss: 0.0191 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 243us/step - loss: 0.0153 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 236us/step - loss: 0.0191 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 259us/step - loss: 0.0242 - accuracy: 0.1939
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 316us/step - loss: 0.0311 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 253us/step - loss: 0.0173 - accuracy: 0.2041
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 259us/step - loss: 0.0146 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 244us/step - loss: 0.0151 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 248us/step - loss: 0.0159 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 259us/step - loss: 0.0174 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 248us/step - loss: 0.0290 - accuracy: 0.1881
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 276us/step - loss: 0.0147 - accuracy: 0.2041
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 258us/step - loss: 0.0208 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 294us/step - loss: 0.0136 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 255us/step - loss: 0.0126 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 262us/step - loss: 0.0149 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 253us/step - loss: 0.0276 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 265us/step - loss: 0.0090 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 253us/step - loss: 0.0204 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 240us/step - loss: 0.0122 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 247us/step - loss: 0.0140 - accuracy: 0.0779
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 255us/step - loss: 0.0139 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 287us/step - loss: 0.0268 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 261us/step - loss: 0.0114 - accuracy: 0.2041
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 259us/step - loss: 0.0197 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 242us/step - loss: 0.0095 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 257us/step - loss: 0.0140 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 263us/step - loss: 0.0161 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 252us/step - loss: 0.0314 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 262us/step - loss: 0.0117 - accuracy: 0.2041
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 268us/step - loss: 0.0166 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 236us/step - loss: 0.0214 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 253us/step - loss: 0.0166 - accuracy: 0.0779
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 269us/step - loss: 0.0191 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 245us/step - loss: 0.0241 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 251us/step - loss: 0.0218 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 262us/step - loss: 0.0177 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 251us/step - loss: 0.0136 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 261us/step - loss: 0.0149 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 262us/step - loss: 0.0123 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 250us/step - loss: 0.0248 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 299us/step - loss: 0.0090 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 259us/step - loss: 0.0136 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 244us/step - loss: 0.0089 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 252us/step - loss: 0.0130 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 262us/step - loss: 0.0118 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 256us/step - loss: 0.0272 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 270us/step - loss: 0.0091 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 266us/step - loss: 0.0157 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 229us/step - loss: 0.0099 - accuracy: 0.1981
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 253us/step - loss: 0.0143 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 317us/step - loss: 0.0134 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 255us/step - loss: 0.0211 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 258us/step - loss: 0.0120 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 255us/step - loss: 0.0161 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 238us/step - loss: 0.0136 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 249us/step - loss: 0.0114 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 246us/step - loss: 0.0120 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 265us/step - loss: 0.0237 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 256us/step - loss: 0.0083 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 280us/step - loss: 0.0132 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 236us/step - loss: 0.0088 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 252us/step - loss: 0.0082 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 261us/step - loss: 0.0138 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 246us/step - loss: 0.0220 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 257us/step - loss: 0.0118 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 252us/step - loss: 0.0153 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 234us/step - loss: 0.0095 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 245us/step - loss: 0.0087 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 263us/step - loss: 0.0105 - accuracy: 0.2041
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 242us/step - loss: 0.0216 - accuracy: 0.1980
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 257us/step - loss: 0.0080 - accuracy: 0.2143
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 262us/step - loss: 0.0138 - accuracy: 0.2165
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 245us/step - loss: 0.0069 - accuracy: 0.2075
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 257us/step - loss: 0.0096 - accuracy: 0.0909
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 258us/step - loss: 0.0122 - accuracy: 0.2041
# {'Germany': [[0.149266918992052], [0.07172745362956925], [0.03628475935023168], [0.027980433380471008], [0.031128301257544226], [0.02897395709953686], [0.0276080539800448], [0.026799909512300303], [0.0313976824947513], [0.024136178619643248], [0.02477506690169915], [0.027156625164322334], [0.021066690882723227], [0.023666045895897516], [0.02202418859642331], [0.02158290348799512]], 'United_Kingdom': [[0.14202860605959988], [0.0426435329172076], [0.01633454501932981], [0.012812607498763472], [0.017308284661599567], [0.014702261178469171], [0.008994259111279128], [0.011390268767005478], [0.011745925751581256], [0.021805939145804365], [0.008993013569495964], [0.009084382839263322], [0.012037185418695135], [0.008271484084579409], [0.01184519395536306], [0.00800704538622605]], 'Spain': [[0.0913264816722919], [0.0358987773922224], [0.019257928098350304], [0.019148907334947018], [0.01461893679170879], [0.020763813431576354], [0.02041406114345666], [0.019695622529642482], [0.016604978552798636], [0.01774429929317887], [0.013564167544095701], [0.015666846454758004], [0.016116759711012396], [0.013154420800046208], [0.01529472231620097], [0.013818886908750558]], 'United_States_of_America': [[0.06458386272754309], [0.031170486208965193], [0.015254485965618547], [0.015301867634198576], [0.015095848238693093], [0.013630736320507977], [0.01215403760730658], [0.00954124044170076], [0.021384185285500762], [0.013645802769493664], [0.008876587176379168], [0.009889360482119164], [0.01360973166653289], [0.00877164898194232], [0.009531500292414764], [0.0069140383341121225]], 'Brazil': [[0.05120704748800823], [0.026706204737548703], [0.017371572457350694], [0.019062278284267944], [0.01588628057075979], [0.012611500096398515], [0.013962591913613405], [0.01396677957533242], [0.01659354782820522], [0.014935036080998259], [0.012982596365081799], [0.01432514118103238], [0.011440143581818451], [0.008167947848121842], [0.008735165054389796], [0.009608905175821735]], 'Italy': [[0.08058643523527652], [0.029200334444033856], [0.021925752412299722], [0.024240593520962462], [0.017441611679993113], [0.014935415152612389], [0.0138941013767403], [0.016147904402139236], [0.01910166214315259], [0.012277905867263978], [0.011801652534275639], [0.013396069369449908], [0.012004024702556697], [0.0138028331566602], [0.010503660487153624], [0.01219023387803107]]}
# CPU times: user 5.42 s, sys: 504 ms, total: 5.92 s
# Wall time: 4.44 s

# %%
# %%time
# epochs = 5
# The RNN architecture
regressorRNN_deaths = Sequential()
# First RNN layer with Dropout regularisation
regressorRNN_deaths.add(SimpleRNN(units=50, return_sequences=True, input_shape=(look_back_deaths,1)))
regressorRNN_deaths.add(Dropout(0.2))
# Second RNN layer
regressorRNN_deaths.add(SimpleRNN(units=50, return_sequences=True))
regressorRNN_deaths.add(Dropout(0.2))
# Third RNN layer
regressorRNN_deaths.add(SimpleRNN(units=50, return_sequences=True))
regressorRNN_deaths.add(Dropout(0.5))
# Fourth RNN layer
regressorRNN_deaths.add(SimpleRNN(units=50))
regressorRNN_deaths.add(Dropout(0.5))
# The output layer
regressorRNN_deaths.add(Dense(units=1))

# Compiling the RNN
regressorRNN_deaths.compile(optimizer='rmsprop', loss='mean_squared_error', metrics = ['accuracy'])
# Fitting to the training set
history_deaths = {}
for country in training_countries:
  history_deaths[country] = []
for epoch in range(epochs):
    for country in training_countries:
        print("Fitting to", country)
        H = regressorRNN_deaths.fit(trainset_deaths[country]["X"], trainset_deaths[country]["y"], epochs=1, batch_size=16)
        history_deaths[country].append(H.history["loss"])
print(history_deaths)

plt.style.use("ggplot")
plt.figure()
for country in training_countries:
  plt.plot(np.arange(0, epochs), history_deaths[country], label=country)
plt.title("Training Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="upper right")
# Out:
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 5ms/step - loss: 0.2959 - accuracy: 0.4455
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 273us/step - loss: 0.2895 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 277us/step - loss: 0.2819 - accuracy: 0.3299
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 252us/step - loss: 0.1392 - accuracy: 0.3679
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 270us/step - loss: 0.1480 - accuracy: 0.2338
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 258us/step - loss: 0.2548 - accuracy: 0.2143
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 252us/step - loss: 0.1447 - accuracy: 0.4257
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 263us/step - loss: 0.2029 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 264us/step - loss: 0.2130 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 267us/step - loss: 0.0657 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 268us/step - loss: 0.0797 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 266us/step - loss: 0.2532 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 260us/step - loss: 0.1300 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 267us/step - loss: 0.1789 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 273us/step - loss: 0.1495 - accuracy: 0.3402
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 260us/step - loss: 0.0585 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 266us/step - loss: 0.0743 - accuracy: 0.2338
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 267us/step - loss: 0.0926 - accuracy: 0.2143
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 262us/step - loss: 0.0965 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 266us/step - loss: 0.1559 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 272us/step - loss: 0.1095 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 255us/step - loss: 0.0410 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 271us/step - loss: 0.0450 - accuracy: 0.2338
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 284us/step - loss: 0.1426 - accuracy: 0.2143
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 270us/step - loss: 0.0494 - accuracy: 0.4455
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 303us/step - loss: 0.1020 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 294us/step - loss: 0.1237 - accuracy: 0.3402
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 291us/step - loss: 0.0247 - accuracy: 0.3679
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 267us/step - loss: 0.0402 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 296us/step - loss: 0.1247 - accuracy: 0.2143
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 263us/step - loss: 0.0926 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 275us/step - loss: 0.0794 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 270us/step - loss: 0.0543 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 270us/step - loss: 0.0302 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 279us/step - loss: 0.0220 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 314us/step - loss: 0.0538 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 288us/step - loss: 0.0779 - accuracy: 0.4257
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 286us/step - loss: 0.0902 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 275us/step - loss: 0.0842 - accuracy: 0.3402
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 254us/step - loss: 0.0248 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 283us/step - loss: 0.0334 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 369us/step - loss: 0.0583 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 289us/step - loss: 0.0493 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 298us/step - loss: 0.0562 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 267us/step - loss: 0.0640 - accuracy: 0.3402
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 259us/step - loss: 0.0276 - accuracy: 0.3679
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 265us/step - loss: 0.0309 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 269us/step - loss: 0.0595 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 273us/step - loss: 0.0605 - accuracy: 0.4257
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 280us/step - loss: 0.0641 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 294us/step - loss: 0.0555 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 277us/step - loss: 0.0273 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 284us/step - loss: 0.0452 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 268us/step - loss: 0.0483 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 312us/step - loss: 0.0470 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 292us/step - loss: 0.0520 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 295us/step - loss: 0.0359 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 283us/step - loss: 0.0240 - accuracy: 0.3679
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 327us/step - loss: 0.0229 - accuracy: 0.2338
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 293us/step - loss: 0.0575 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 265us/step - loss: 0.0388 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 272us/step - loss: 0.0536 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 301us/step - loss: 0.0466 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 274us/step - loss: 0.0239 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 290us/step - loss: 0.0336 - accuracy: 0.2338
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 276us/step - loss: 0.0455 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 274us/step - loss: 0.0425 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 296us/step - loss: 0.0550 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 271us/step - loss: 0.0506 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 292us/step - loss: 0.0214 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 299us/step - loss: 0.0336 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 285us/step - loss: 0.0327 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 287us/step - loss: 0.0449 - accuracy: 0.4257
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 277us/step - loss: 0.0536 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 285us/step - loss: 0.0424 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 277us/step - loss: 0.0146 - accuracy: 0.3679
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 277us/step - loss: 0.0261 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 289us/step - loss: 0.0316 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 324us/step - loss: 0.0420 - accuracy: 0.4356
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 266us/step - loss: 0.0274 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 275us/step - loss: 0.0314 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 279us/step - loss: 0.0238 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 264us/step - loss: 0.0267 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 290us/step - loss: 0.0327 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 287us/step - loss: 0.0249 - accuracy: 0.4455
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 296us/step - loss: 0.0371 - accuracy: 0.3673
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 289us/step - loss: 0.0350 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 245us/step - loss: 0.0159 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 257us/step - loss: 0.0203 - accuracy: 0.2468
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 277us/step - loss: 0.0354 - accuracy: 0.2245
# Fitting to Germany
# Epoch 1/1
# 101/101 [==============================] - 0s 282us/step - loss: 0.0366 - accuracy: 0.4455
# Fitting to United_Kingdom
# Epoch 1/1
# 98/98 [==============================] - 0s 297us/step - loss: 0.0454 - accuracy: 0.3571
# Fitting to Spain
# Epoch 1/1
# 97/97 [==============================] - 0s 305us/step - loss: 0.0295 - accuracy: 0.3505
# Fitting to United_States_of_America
# Epoch 1/1
# 106/106 [==============================] - 0s 280us/step - loss: 0.0283 - accuracy: 0.3585
# Fitting to Brazil
# Epoch 1/1
# 77/77 [==============================] - 0s 269us/step - loss: 0.0284 - accuracy: 0.2338
# Fitting to Italy
# Epoch 1/1
# 98/98 [==============================] - 0s 292us/step - loss: 0.0277 - accuracy: 0.2245
# {'Germany': [[0.29586991658526485], [0.14467162070888104], [0.1300456554877876], [0.09653737159943816], [0.049408917472061546], [0.09263356373009116], [0.07793346121169553], [0.04934600843946532], [0.060540939395380494], [0.04701396821085179], [0.03877757851145055], [0.04249779828409157], [0.04487671651923568], [0.04196048181245823], [0.02485188447160296], [0.03657676759037641]], 'United_Kingdom': [[0.2895410964621839], [0.2029446693783512], [0.17887006842588282], [0.1558676866092244], [0.10196287717138018], [0.07942393224458305], [0.0902056514228485], [0.05622070377730593], [0.0641343292533135], [0.052047816456808726], [0.05364690797061336], [0.055004319708262174], [0.053588642301608105], [0.027364162005940263], [0.037053141339054824], [0.04537117147666155]], 'Spain': [[0.2819300856172424], [0.2130142386868289], [0.14947934964306883], [0.10954897551192451], [0.12372943284242059], [0.054319299767081886], [0.08416990046725445], [0.06403911113739014], [0.05547804008093998], [0.0359216582380504], [0.04662814524778424], [0.05055019025542034], [0.042367420099272406], [0.03142905742237248], [0.03498845693376875], [0.029466643862253908]], 'United_States_of_America': [[0.13923234759636646], [0.06568876028342067], [0.0584622416293846], [0.041047201474320213], [0.024696458201363403], [0.030237215448100613], [0.024787762079317616], [0.02758104087046857], [0.027252738566120278], [0.02395925960802245], [0.023897981482013216], [0.021350290090337676], [0.014594773357769228], [0.023769314682005712], [0.01585549977168722], [0.02832857588798089]], 'Brazil': [[0.1479797884338088], [0.07965435075585718], [0.07425548262023307], [0.045009150810830005], [0.04020877888837418], [0.022001670141305243], [0.033358134159987625], [0.03091429319692316], [0.04521735186700697], [0.022883714382331093], [0.03357968847085903], [0.0335926694142354], [0.026126347433824044], [0.02669410847804763], [0.02026192531860494], [0.028396781993570267]], 'Italy': [[0.25478680036505874], [0.25324597996564546], [0.0925596219544508], [0.14259541787359178], [0.12470710931383834], [0.05377402335253297], [0.05828149563499859], [0.05950001490359404], [0.048345938324928284], [0.05747808348530029], [0.04545184909080972], [0.032694326019940934], [0.0316403619184786], [0.0326991535875262], [0.03539162912947715], [0.027670216271463707]]}
# CPU times: user 5.97 s, sys: 490 ms, total: 6.46 s
# Wall time: 4.94 s

# %%
pred_result_cases = {}
for country in training_countries:
    y_true = scaler_cases[country].inverse_transform(testset_cases[country]["y"].reshape(-1,1))
    y_pred = scaler_cases[country].inverse_transform(regressorRNN_cases.predict(testset_cases[country]["X"]))
    MSE = mean_squared_error(y_true, y_pred)
    pred_result_cases[country] = {}
    pred_result_cases[country]["True"] = y_true
    pred_result_cases[country]["Pred"] = y_pred

pred_result_deaths = {}
for country in training_countries:
    y_true = scaler_deaths[country].inverse_transform(testset_deaths[country]["y"].reshape(-1,1))
    y_pred = scaler_deaths[country].inverse_transform(regressorRNN_deaths.predict(testset_deaths[country]["X"]))
    MSE = mean_squared_error(y_true, y_pred)
    pred_result_deaths[country] = {}
    pred_result_deaths[country]["True"] = y_true
    pred_result_deaths[country]["Pred"] = y_pred

# %%
total_error["Cases"] = 0
for country in training_countries:
  total_error["Cases"] +=lagging(pred_result_cases[country], -3)

# %%
total_error["Deaths"] = 0
for country in training_countries:
  total_error["Deaths"] +=lagging(pred_result_deaths[country], -3)
# Out:
# MSE with Lag    : 0.0850935548824342
# MSE with Lag    : 0.8119550732851305
# MSE with Lag    : 0.15236032966233848
# MSE with Lag    : 0.3036799717119963
# MSE with Lag    : 0.3357438373677351
# MSE with Lag    : 0.7146888005482324

# %%
FILE = open('RNNcases.pickle', 'wb')
pickle.dump(regressorRNN_cases, FILE)
FILE.close()

FILE = open('RNNdeaths.pickle', 'wb')
pickle.dump(regressorRNN_deaths, FILE)
FILE.close()

# %%
print(total_error)
# Out:
# {'Cases': 0, 'Deaths': 2.403521567457867}

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df_latest = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/data.csv')
df_latest.head()
# Out:
#       dateRep  day  month  ...  countryterritoryCode  popData2018  continentExp
# 0  12-06-2020   12      6  ...                   AFG   37172386.0          Asia
# 1  11-06-2020   11      6  ...                   AFG   37172386.0          Asia
# 2  10-06-2020   10      6  ...                   AFG   37172386.0          Asia
# 3  09-06-2020    9      6  ...                   AFG   37172386.0          Asia
# 4  08-06-2020    8      6  ...                   AFG   37172386.0          Asia
#
# [5 rows x 11 columns]

# %%
FILE = open('RNNcases.pickle', 'rb')
RNN_cases = pickle.load(FILE)
FILE.close()

FILE = open('RNNdeaths.pickle', 'rb')
RNN_deaths = pickle.load(FILE)
FILE.close()

# %%
grouped = df_latest.groupby('countriesAndTerritories')
countries=sorted(list(set(df_latest.countriesAndTerritories.unique())))
country_population = {}
for country in countries:
  country_population[country]=set(grouped.get_group(country)['popData2018'])
countries_to_remove = ["Cases_on_an_international_conveyance_Japan", "Holy_See"]
for country in countries:
  if len(country_population[country])>1 :
    countries_to_remove.append(country)
for country in countries_to_remove:
  del country_population[country]
  countries.remove(country)

country_population = {}
for country in countries:
  country_population[country]=list(grouped.get_group(country)['popData2018'])[0]

# %%
country_wise_cases=dict()
country_wise_deaths=dict()
normalised_country_wise_cases=dict()
normalised_country_wise_deaths=dict()
for country in countries:
  country_wise_cases[country]=list(grouped.get_group(country)['cases'])[::-1]
  country_wise_deaths[country]=list(grouped.get_group(country)['deaths'])[::-1]
for country in countries:
  for index in range(len(country_wise_cases[country])):
    country_wise_cases[country][index] = abs(country_wise_cases[country][index])
    country_wise_deaths[country][index] = abs(country_wise_deaths[country][index])

for country in countries:
  leading_zero_count = 0
  for index in range(len(country_wise_cases[country])):
    if country_wise_cases[country][index] == 0:
      leading_zero_count += 1
    else:
      country_wise_cases[country] = country_wise_cases[country][leading_zero_count:]
      country_wise_deaths[country] = country_wise_deaths[country][leading_zero_count:]
      break

# %%
for country in countries:
  normalised_country_wise_cases[country] = deepcopy(country_wise_cases[country])
  for index in range(len(country_wise_cases[country])):
    normalised_country_wise_cases[country][index] = normalised_country_wise_cases[country][index] * 1_000_000 / country_population[country]

for country in countries:
  normalised_country_wise_deaths[country] = deepcopy(country_wise_deaths[country])
  for index in range(len((country_wise_deaths[country]))):
    normalised_country_wise_deaths[country][index] = normalised_country_wise_deaths[country][index] * 1_000_000 / country_population[country]

# %%
cumulative_country_wise_cases=dict()
cumulative_country_wise_deaths=dict()
normalised_cumulative_country_wise_cases=dict()
normalised_cumulative_country_wise_deaths=dict()

for country in countries:
  cumulative_country_wise_cases[country] = []
  cumulative_country_wise_deaths[country] = []
  cumulative_cases = 0
  cumulative_death = 0
  normalised_cumulative_country_wise_cases[country] = []
  normalised_cumulative_country_wise_deaths[country] = []
  normalised_cumulative_cases = 0
  normalised_cumulative_death = 0
  total_days = len(country_wise_cases[country])
  for index in range(total_days):
    cumulative_cases += country_wise_cases[country][index]
    cumulative_death += country_wise_deaths[country][index]
    cumulative_country_wise_cases[country].append(cumulative_cases)
    cumulative_country_wise_deaths[country].append(cumulative_death)
    normalised_cumulative_cases += normalised_country_wise_cases[country][index]
    normalised_cumulative_death += normalised_country_wise_deaths[country][index]
    normalised_cumulative_country_wise_cases[country].append(normalised_cumulative_cases)
    normalised_cumulative_country_wise_deaths[country].append(normalised_cumulative_death)

# %%
for country in countries:
  print("{0:45s}".format(country),"{0:10d}".format(cumulative_country_wise_cases[country][-1]),"{0:10d}".format(cumulative_country_wise_deaths[country][-1]))
# Out:
# Afghanistan                                        22890        426
# Albania                                             1385         35
# Algeria                                            10589        741
# Andorra                                              852         51
# Angola                                               118          5
# Antigua_and_Barbuda                                   26          3
# Argentina                                          27360        765
# Armenia                                            14669        245
# Aruba                                                101          3
# Australia                                           7285        102
# Austria                                            16964        674
# Azerbaijan                                          8882        108
# Bahamas                                              103         11
# Bahrain                                            17269         36
# Bangladesh                                         78052       1049
# Barbados                                              96          7
# Belarus                                            51816        293
# Belgium                                            59711       9636
# Belize                                                19          2
# Benin                                                723          4
# Bermuda                                              141          9
# Bhutan                                                62          0
# Bolivia                                            16165        533
# Bosnia_and_Herzegovina                              2831        160
# Botswana                                              48          1
# Brazil                                            802828      40919
# British_Virgin_Islands                                 8          1
# Brunei_Darussalam                                    141          2
# Bulgaria                                            3086        168
# Burkina_Faso                                         892         53
# Burundi                                               94          1
# Cambodia                                             126          0
# Cameroon                                            8681        208
# Canada                                             97519       7994
# Cape_Verde                                           657          6
# Cayman_Islands                                       180          1
# Central_African_Republic                            2044          7
# Chad                                                 848         72
# Chile                                             154092       2648
# China                                              84216       4638
# Colombia                                           43682       1433
# Comoros                                              162          2
# Congo                                                745         25
# Costa_Rica                                          1538         12
# Cote_dIvoire                                        4404         41
# Croatia                                             2249        106
# Cuba                                                2219         84
# Curaçao                                               22          1
# Cyprus                                               975         18
# Czechia                                             9886        329
# Democratic_Republic_of_the_Congo                    4514         97
# Denmark                                            12035        593
# Djibouti                                            4398         37
# Dominica                                              18          0
# Dominican_Republic                                 21437        561
# Ecuador                                            52422       3720
# Egypt                                              39726       1377
# El_Salvador                                         3481         68
# Equatorial_Guinea                                   1306         12
# Estonia                                             1965         69
# Eswatini                                             449          3
# Ethiopia                                            2670         40
# Faroe_Islands                                        187          0
# Fiji                                                  18          0
# Finland                                             7064        325
# France                                            157093      29346
# French_Polynesia                                      60          0
# Gabon                                               3463         23
# Gambia                                                28          1
# Georgia                                              831         13
# Germany                                           185674       8763
# Ghana                                              10358         48
# Gibraltar                                            176          0
# Greece                                              3088        183
# Greenland                                             13          0
# Grenada                                               23          0
# Guam                                                 182          5
# Guatemala                                           8561        334
# Guernsey                                             252         13
# Guinea                                              4372         23
# Guinea_Bissau                                       1389         12
# Guyana                                               158         12
# Haiti                                               3941         64
# Honduras                                            7669        294
# Hungary                                             4039        553
# Iceland                                             1807         10
# India                                             297535       8498
# Indonesia                                          35295       2000
# Iran                                              180176       8584
# Iraq                                               16675        457
# Ireland                                            25238       1703
# Isle_of_Man                                          336         24
# Israel                                             18701        300
# Italy                                             236142      34167
# Jamaica                                              611         10
# Japan                                              17332        922
# Jersey                                               313         30
# Jordan                                               890          9
# Kazakhstan                                         13872         67
# Kenya                                               3215         92
# Kosovo                                              1326         31
# Kuwait                                             34432        279
# Kyrgyzstan                                          2166         26
# Laos                                                  19          0
# Latvia                                              1094         26
# Lebanon                                             1402         31
# Lesotho                                                4          0
# Liberia                                              410         31
# Libya                                                393          5
# Liechtenstein                                         83          1
# Lithuania                                           1962         74
# Luxembourg                                          4052        110
# Madagascar                                          1203         10
# Malawi                                               481          4
# Malaysia                                            8369        118
# Maldives                                            1976          8
# Mali                                                1722         97
# Malta                                                640          9
# Mauritania                                          1162         61
# Mauritius                                            337         10
# Mexico                                            133974      15944
# Moldova                                            10727        375
# Monaco                                                99          5
# Mongolia                                             197          0
# Montenegro                                           324          9
# Montserrat                                            11          1
# Morocco                                             8537        211
# Mozambique                                           489          2
# Myanmar                                              261          6
# Namibia                                               31          0
# Nepal                                               4614         15
# Netherlands                                        48251       6044
# New_Caledonia                                         21          0
# New_Zealand                                         1154         22
# Nicaragua                                           1464         55
# Niger                                                974         65
# Nigeria                                            14554        387
# North_Macedonia                                     3542        169
# Northern_Mariana_Islands                              30          2
# Norway                                              8594        242
# Oman                                               19954         89
# Pakistan                                          125933       2463
# Palestine                                            667          5
# Panama                                             18586        590
# Papua_New_Guinea                                       8          0
# Paraguay                                            1230         11
# Peru                                              214788       6109
# Philippines                                        24175       1036
# Poland                                             28201       1215
# Portugal                                           36232       1504
# Puerto_Rico                                         5352        144
# Qatar                                              75071         69
# Romania                                            21182       1369
# Russia                                            502436       6532
# Rwanda                                               494          2
# Saint_Kitts_and_Nevis                                 15          0
# Saint_Lucia                                           19          0
# Saint_Vincent_and_the_Grenadines                      27          0
# San_Marino                                           709         42
# Sao_Tome_and_Principe                                639         12
# Saudi_Arabia                                      116021        857
# Senegal                                             4759         56
# Serbia                                             12102        252
# Seychelles                                            11          0
# Sierra_Leone                                        1085         50
# Singapore                                          39387         25
# Sint_Maarten                                          77         15
# Slovakia                                            1541         28
# Slovenia                                            1488        109
# Somalia                                             2513         85
# South_Africa                                       58568       1289
# South_Korea                                        12003        277
# South_Sudan                                         1604         19
# Spain                                             244877      30972
# Sri_Lanka                                           1877         11
# Sudan                                               6730        413
# Suriname                                             168          2
# Sweden                                             48288       4814
# Switzerland                                        30961       1674
# Syria                                                164          6
# Taiwan                                               443          7
# Tajikistan                                          4834         49
# Thailand                                            3125         58
# Timor_Leste                                           24          0
# Togo                                                 524         13
# Trinidad_and_Tobago                                  117          8
# Tunisia                                             1087         49
# Turkey                                            174023       4763
# Turks_and_Caicos_islands                              12          1
# Uganda                                               911          0
# Ukraine                                            29070        854
# United_Arab_Emirates                               40986        286
# United_Kingdom                                    292459      41279
# United_Republic_of_Tanzania                          509         21
# United_States_Virgin_Islands                          72          6
# United_States_of_America                         2023347     113820
# Uruguay                                              847         23
# Uzbekistan                                          4819         19
# Venezuela                                           2814         23
# Vietnam                                              332          0
# Yemen                                                591        136
# Zambia                                              1252         10
# Zimbabwe                                             332          4

# %%
top_n = 10
countries_and_cases=[]
countries_and_deaths=[]

for country,cumulative_cases in zip(cumulative_country_wise_cases.keys(),cumulative_country_wise_cases.values()):
  countries_and_cases.append([country,cumulative_cases[-1]])
countries_and_cases=sorted(countries_and_cases,key=lambda x:x[1],reverse=True)
top_n_cases=list(map(lambda x:x[0],countries_and_cases))[:top_n]

for country,cumulative_deaths in zip(cumulative_country_wise_deaths.keys(),cumulative_country_wise_deaths.values()):
  countries_and_deaths.append([country,cumulative_deaths[-1]])
countries_and_deaths=sorted(countries_and_deaths,key=lambda x:x[1],reverse=True)

top_n_deaths=list(map(lambda x:x[0],countries_and_deaths))[:top_n]

print("{0:45s}".format("Total Cases"), "{0:45s}".format("Total Deaths"), end="\n\n")
for index in range(top_n):
  print("{0:45s}".format(top_n_cases[index]), "{0:45s}".format(top_n_deaths[index]))

def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2)) 
training_countries = list(intersection(top_n_cases, top_n_deaths))
print(training_countries)
# Out:
# Total Cases                                   Total Deaths
#
# United_States_of_America                      United_States_of_America
# Brazil                                        United_Kingdom
# Russia                                        Brazil
# India                                         Italy
# United_Kingdom                                Spain
# Spain                                         France
# Italy                                         Mexico
# Peru                                          Belgium
# Germany                                       Germany
# Iran                                          Iran
# ['Germany', 'United_Kingdom', 'Spain', 'United_States_of_America', 'Iran', 'Brazil', 'Italy']

# %%
base_data_cases = normalised_country_wise_cases
base_data_deaths = normalised_country_wise_deaths

def split(dataframe, split_factor):
  base_data = {}
  for country in training_countries:
    base_data[country] = {}
    country_data_length = len(dataframe[country])
    split_index = int(math.floor(country_data_length * split_factor))
    base_data[country]["Train"] = dataframe[country][:split_index]
    base_data[country]["Test"] = dataframe[country][split_index:]
  return base_data

split_factor = 0.8

transform_train_cases = {}
transform_test_cases = {}
scaler_cases = {}
data_cases = split(base_data_cases, split_factor)
for num, country in enumerate(training_countries):
    sc = MinMaxScaler(feature_range=(0,1))
    a0 = np.array(data_cases[country]["Train"])
    a1 = np.array(data_cases[country]["Test"])
    a0 = a0.reshape(a0.shape[0],1)
    a1 = a1.reshape(a1.shape[0],1)
    transform_train_cases[country] = sc.fit_transform(a0)
    transform_test_cases[country] = sc.fit_transform(a1)
    scaler_cases[country] = sc
del a0
del a1

transform_train_deaths = {}
transform_test_deaths = {}
scaler_deaths = {}
data_deaths = split(base_data_deaths, split_factor)
for num, country in enumerate(training_countries):
    sc = MinMaxScaler(feature_range=(0,1))
    a0 = np.array(data_deaths[country]["Train"])
    a1 = np.array(data_deaths[country]["Test"])
    a0 = a0.reshape(a0.shape[0],1)
    a1 = a1.reshape(a1.shape[0],1)
    transform_train_deaths[country] = sc.fit_transform(a0)
    transform_test_deaths[country] = sc.fit_transform(a1)
    scaler_deaths[country] = sc
del a0
del a1

# %%
for i in transform_train_cases.keys():
    print(i, transform_train_cases[i].shape)
print("\n")    
for i in transform_test_cases.keys():
    print(i, transform_test_cases[i].shape)
 
print("\n")    
for i in transform_train_deaths.keys():
    print(i, transform_train_deaths[i].shape)
print("\n")    
for i in transform_test_deaths.keys():
    print(i, transform_test_deaths[i].shape)
# Out:
# Germany (109, 1)
# United_Kingdom (107, 1)
# Spain (105, 1)
# United_States_of_America (115, 1)
# Iran (91, 1)
# Brazil (86, 1)
# Italy (107, 1)
#
#
# Germany (28, 1)
# United_Kingdom (27, 1)
# Spain (27, 1)
# United_States_of_America (29, 1)
# Iran (23, 1)
# Brazil (22, 1)
# Italy (27, 1)
#
#
# Germany (109, 1)
# United_Kingdom (107, 1)
# Spain (105, 1)
# United_States_of_America (115, 1)
# Iran (91, 1)
# Brazil (86, 1)
# Italy (107, 1)
#
#
# Germany (28, 1)
# United_Kingdom (27, 1)
# Spain (27, 1)
# United_States_of_America (29, 1)
# Iran (23, 1)
# Brazil (22, 1)
# Italy (27, 1)

# %%
trainset_cases = {}
testset_cases = {}
look_back_cases = 3
for country in training_countries:
    trainset_cases[country] = {}
    X_train = []
    y_train = []
    for i in range(look_back_cases, len(transform_train_cases[country])):
        X_train.append(transform_train_cases[country][i-look_back_cases:i,0])
        y_train.append(transform_train_cases[country][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset_cases[country]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset_cases[country]["y"] = y_train
    
    testset_cases[country] = {}
    X_test = []
    y_test = []    
    for i in range(look_back_cases, len(transform_test_cases[country])):
        X_test.append(transform_test_cases[country][i-look_back_cases:i,0])
        y_test.append(transform_test_cases[country][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset_cases[country]["X"] = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
    testset_cases[country]["y"] = y_test

trainset_deaths = {}
testset_deaths = {}
look_back_deaths = 3
for country in training_countries:
    trainset_deaths[country] = {}
    X_train = []
    y_train = []
    for i in range(look_back_deaths, len(transform_train_deaths[country])):
        X_train.append(transform_train_deaths[country][i-look_back_deaths:i,0])
        y_train.append(transform_train_deaths[country][i,0])
    X_train, y_train = np.array(X_train), np.array(y_train)
    trainset_deaths[country]["X"] = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
    trainset_deaths[country]["y"] = y_train
    
    testset_deaths[country] = {}
    X_test = []
    y_test = []    
    for i in range(look_back_deaths, len(transform_test_deaths[country])):
        X_test.append(transform_test_deaths[country][i-look_back_deaths:i,0])
        y_test.append(transform_test_deaths[country][i,0])
    X_test, y_test = np.array(X_test), np.array(y_test)
    testset_deaths[country]["X"] = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
    testset_deaths[country]["y"] = y_test

# %%
for country in training_countries:
  normalised_country_wise_cases[country] = np.array(normalised_country_wise_cases[country])
  normalised_country_wise_deaths[country] = np.array(normalised_country_wise_deaths[country])

# %%
pred_result_cases = {}
for country in training_countries:
  y_true = scaler_cases[country].inverse_transform(testset_cases[country]["y"].reshape(-1,1))
  y_pred = scaler_cases[country].inverse_transform(RNN_cases.predict(testset_cases[country]["X"]))
  MSE = mean_squared_error(y_true, y_pred)
  pred_result_cases[country] = {}
  pred_result_cases[country]["True"] = y_true
  pred_result_cases[country]["Pred"] = y_pred

pred_result_deaths = {}
for country in training_countries:
  y_true = scaler_deaths[country].inverse_transform(testset_deaths[country]["y"].reshape(-1,1))
  y_pred = scaler_deaths[country].inverse_transform(RNN_deaths.predict(testset_deaths[country]["X"]))
  MSE = mean_squared_error(y_true, y_pred)
  pred_result_deaths[country] = {}
  pred_result_deaths[country]["True"] = y_true
  pred_result_deaths[country]["Pred"] = y_pred

# %%
total_error["Cases"] = 0
for country in training_countries:
  total_error["Cases"] += lagging(pred_result_cases[country], -3)
# Out:
# MSE with Lag    : 4.213707008705494
# MSE with Lag    : 260.5864432174892
# MSE with Lag    : 73.15823144753917
# MSE with Lag    : 39.021062655029674
# MSE with Lag    : 3.5030244374872423
# MSE with Lag    : 380.2098087815393
# MSE with Lag    : 2.2853550845581787

# %%
total_error["Deaths"] = 0
for country in training_countries:
  total_error["Deaths"] +=lagging(pred_result_deaths[country], -3)
# Out:
# MSE with Lag    : 0.05580581042900146
# MSE with Lag    : 1.9423860110000006
# MSE with Lag    : 8.566193867444818
# MSE with Lag    : 0.5377399684971457
# MSE with Lag    : 0.011992764562853976
# MSE with Lag    : 0.19230456884739133
# MSE with Lag    : 0.16100442637442178

# %%
print(total_error)
# Out:
# {'Cases': 762.9776326323483, 'Deaths': 11.467427417155632}
